# %%
#Librerías necesarias
from random import random
import matplotlib.pyplot as plt
import statistics
import math

#Cambio tamaño de imagenes
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
#Definimos función uniforme
#Tomamos un A cualquiera
A=1
#Tomamos un B cualquiera
B=10

def uniforme(a,b):
    r = random() #función random toma cualquier valor entre 0 y 1
    x = a + (b-a)*r #transformada inversa para la función de distribución acumulada
    return x

# %%
#Generamos n resultados con distribución uniforme
n = 1000
resultados_uniforme = []
for i in range(n):
    resultados_uniforme.append(uniforme(A,B))

# %%
#Calculamos esperanza y varianza de la muestra y las comparamos con los valores teóricos

#Esperanza
esperanza = statistics.mean(resultados_uniforme)

#Varianza
varianza = statistics.pvariance(resultados_uniforme)

print("Esperanza: ", esperanza, "- Esperanza teorica: ", (A+B)/2)
print("Varianza: ",varianza, "- Varianza teorica: ", (B-A)**2/12)
# Out:
# Esperanza:  5.479497245401613 - Esperanza teorica:  5.5
# Varianza:  6.915612453334058 - Varianza teorica:  6.75

# %%
#Histograma distribución uniforme con valores generados
plt.hist(resultados_uniforme,alpha=1, edgecolor = 'black',  linewidth=1)
plt.grid(True)
plt.title('HISTOGRAMA VALORES GENERADOS - UNIFORME')  # Colocamos el titulo
plt.xlabel('intervalos de clases') # Nombre x
plt.ylabel('frecuencia absoluta') # Nombre y
plt.show()
plt.clf()

# %%
#Definimos función exponencial

def exponencial(ex):
    r = random() #función random toma cualquier valor entre 0 y 1
    #math.log(r[, base]) por defecto la base es 'e'
    x = -ex*math.log(r) #transformada inversa para la función de distribución acumulada
    return x

# %%
#Tomamos un valor de esperanza
EX = 3

#Generamos n resultados con distribución exponencial
n = 1000
resultados_exponencial = []
for i in range(n):
    resultados_exponencial.append(exponencial(EX))

# %%
#Calculamos esperanza y varianza de la muestra y las comparamos con los valores teóricos

#Esperanza
esperanza = statistics.mean(resultados_exponencial)

#Varianza
varianza = statistics.pvariance(resultados_exponencial)

print("Esperanza: ", esperanza, "- Esperanza teorica: ", EX)
print("Varianza: ",varianza, "- Varianza teorica: ", EX**2)
# Out:
# Esperanza:  2.9561348428333107 - Esperanza teorica:  3
# Varianza:  9.175646076224522 - Varianza teorica:  9

# %%
#Histograma distribución exponencial con valores generados
plt.hist(resultados_exponencial,alpha=1, edgecolor = 'black',  linewidth=1)
plt.grid(True)
plt.title('HISTOGRAMA VALORES GENERADOS - EXPONENCIAL')  # Colocamos el titulo
plt.xlabel('intervalos de clases') # Nombre x
plt.ylabel('frecuencia absoluta') # Nombre y
plt.show()
plt.clf()

# %%
#Definimos función gamma
def gamma(k,alfa): 
    producto = 1
    for i in range(1,k+1):
        r = random() #función random toma cualquier valor entre 0 y 1
        producto = producto*r
    #math.log(r[, base]) por defecto la base es 'e'        
    x = -math.log(producto)/alfa #transformada inversa para la función de distribución acumulada
    return x

# %%
#Tomamos cualquier valor de k y alfa
K = 5
ALFA = 0.5

#Generamos n resultados con distribución gamma
n = 1000
resultados_gamma = []
for i in range(n):
    resultados_gamma.append(gamma(K,ALFA))

# %%
#Calculamos esperanza y varianza de la muestra y las comparamos con los valores teóricos

#Esperanza
esperanza = statistics.mean(resultados_gamma)

#Varianza
varianza = statistics.pvariance(resultados_gamma)

print("Esperanza: ", esperanza, "- Esperanza teorica: ", K/ALFA)
print("Varianza: ",varianza, "- Varianza teorica: ", K/ALFA**2)
# Out:
# Esperanza:  10.179606189203124 - Esperanza teorica:  10.0
# Varianza:  20.779344505583165 - Varianza teorica:  20.0

# %%
#Histograma distribución gamma con valores generados
plt.hist(resultados_gamma,alpha=1, edgecolor = 'black',  linewidth=1)
plt.grid(True)
plt.title('HISTOGRAMA VALORES GENERADOS - GAMMA')  # Colocamos el titulo
plt.xlabel('intervalos de clases') # Nombre x
plt.ylabel('frecuencia absoluta') # Nombre y
plt.show()
plt.clf()

# %%
#Tomamos cualquier valor de k
ALFA2 = 1
ALFA3 = 2

#Generamos n resultados con distribución gamma
resultados_gamma_2 = []
for i in range(n):
    resultados_gamma_2.append(gamma(K,ALFA2))    

resultados_gamma_3 = []
for i in range(n):
    resultados_gamma_3.append(gamma(K,ALFA3))  
    
plt.hist(resultados_gamma,alpha=1, edgecolor = 'black',  linewidth=1)
plt.hist(resultados_gamma_2,alpha=1, edgecolor = 'black',  linewidth=1)
plt.hist(resultados_gamma_3,alpha=1, edgecolor = 'black',  linewidth=1)
plt.grid(True)
legend = ['k = {}, alfa = 0.5'.format(K), 'k = {}, alfa = 1'.format(K), 'k = {}, alfa = 2'.format(K)]
plt.legend(legend)
plt.title('COMPARACIÓN HISTOGRAMA - GAMMA')  # Colocamos el titulo
plt.xlabel('intervalos de clases') # Nombre x
plt.ylabel('frecuencia absoluta') # Nombre y
plt.show()
plt.clf()

# %%
#Definimos función normal
#ex esperanza, dx desvio
def normal(ex,dx): 
    suma = 0
    for i in range(12):
        r = random() #función random toma cualquier valor entre 0 y 1
        suma += r
    x = dx*(suma-6)+ex #transformada inversa para la función de distribución acumulada
    return x

# %%
#Tomamos cualquier valor de ex y dx
EX = 3
DX = 1

#Generamos n resultados con distribución normal
n = 1000
resultados_normal = []
for i in range(n):
    resultados_normal.append(normal(EX,DX))

# %%
#Calculamos esperanza y varianza de la muestra y las comparamos con los valores teóricos

#Esperanza
esperanza = statistics.mean(resultados_normal)

#Varianza
varianza = statistics.pvariance(resultados_normal)

print("Esperanza: ", esperanza, "- Esperanza teorica: ", EX)
print("Varianza: ",varianza, "- Varianza teorica: ", DX**2)
# Out:
# Esperanza:  3.0179961125192953 - Esperanza teorica:  3
# Varianza:  1.0496885538725405 - Varianza teorica:  1

# %%
#Histograma distribución normal con valores generados
plt.hist(resultados_normal,alpha=1, edgecolor = 'black',  linewidth=1)
plt.grid(True)
plt.title('HISTOGRAMA VALORES GENERADOS - NORMAL')  # Colocamos el titulo
plt.xlabel('intervalos de clases') # Nombre x
plt.ylabel('frecuencia absoluta') # Nombre y
plt.show()
plt.clf()

# %%
#Definimos función binomial
#p probabilidad de éxito, q = 1-p probabilidad de fracason n2 cantidad de ensayos
def binomial(n2,p): 
    x = 0
    for i in range(1,n2+1):
        r = random() #función random toma cualquier valor entre 0 y 1
        if r-p <= 0:
            x += 1
    return x

# %%
#Tomamos cualquier valor de n2,p
N = 50
P = 0.8

#Generamos n resultados con distribución binomial
n = 1000
resultados_binomial = []
for i in range(n):
    resultados_binomial.append(binomial(N,P))

# %%
#Calculamos esperanza y varianza de la muestra y las comparamos con los valores teóricos

#Esperanza
esperanza = statistics.mean(resultados_binomial)

#Varianza
varianza = statistics.pvariance(resultados_binomial)

print("Esperanza: ", esperanza, "- Esperanza teorica: ", N*P)
print("Varianza: ",varianza, "- Varianza teorica: ", N*P*(1-P))
# Out:
# Esperanza:  39.993 - Esperanza teorica:  40.0
# Varianza:  7.952951 - Varianza teorica:  7.999999999999998

# %%
#Histograma distribución binomial con valores generados
plt.hist(resultados_binomial,alpha=1, edgecolor = 'black',  linewidth=1)
plt.grid(True)
plt.title('HISTOGRAMA VALORES GENERADOS - BINOMIAL')  # Colocamos el titulo
plt.xlabel('intervalos de clases') # Nombre x
plt.ylabel('frecuencia absoluta') # Nombre y
plt.show()
plt.clf()

# %%
#Definimos función poisson
#p probabilidad
def poisson(p): 
    x = 0
    b = math.exp(-p)
    tr = 1
    r = random()
    tr = tr*r
    while tr - b >= 0:
        r = random()
        tr = tr*r
        x += 1
    return x

# %%
#Tomamos cualquier valor de p
P = 0.8

#Generamos n resultados con distribución de poisson
n = 1000
resultados_poisson = []
for i in range(n):
    resultados_poisson.append(poisson(P))

# %%
#Calculamos esperanza y varianza de la muestra y las comparamos con los valores teóricos

#Esperanza
esperanza = statistics.mean(resultados_poisson)

#Varianza
varianza = statistics.pvariance(resultados_poisson)

print("Esperanza: ", esperanza, "- Esperanza teorica: ", P)
print("Varianza: ",varianza, "- Varianza teorica: ", P)
# Out:
# Esperanza:  0.795 - Esperanza teorica:  0.8
# Varianza:  0.7929750000000001 - Varianza teorica:  0.8

# %%
#Histograma distribución poisson con valores generados
plt.hist(resultados_poisson,alpha=1, edgecolor = 'black',  linewidth=1)
plt.grid(True)
plt.title('HISTOGRAMA VALORES GENERADOS - POISSON')  # Colocamos el titulo
plt.xlabel('intervalos de clases') # Nombre x
plt.ylabel('frecuencia absoluta') # Nombre y
plt.show()
plt.clf()
